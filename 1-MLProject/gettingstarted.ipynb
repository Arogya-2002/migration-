# %%
import pandas as pd
from sklearn import datasets
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
import mlflow
from mlflow.models import infer_signature

# %%
##set the tracking uri

mlflow.set_tracking_uri(uri="http://127.0.0.1:5000")

# %%
##load the dataset
X,y=datasets.load_iris(return_X_y=True)
#split the data into training and test sets
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.20)

#define the hyper model parameters

params = {"penalty":"l2","solver":"lbfgs","max_iter":1000,"multi_class":"auto","random_state":8888}

##train the model
lr=LogisticRegression(**params)
lr.fit(X_train,y_train)
# Out:
# c:\Users\SESPL\Desktop\Mlops\mlflow\venv\lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# LogisticRegression(max_iter=1000, multi_class='auto', random_state=8888)

# %%
## prediction on the test set
y_pred = lr.predict(X_test)
y_pred
# Out:
# array([1, 1, 0, 1, 2, 1, 1, 2, 1, 2, 1, 1, 2, 0, 0, 1, 2, 2, 2, 0, 0, 2,
#        2, 1, 2, 1, 1, 2, 2, 0])

# %%
accuracy=accuracy_score(y_test,y_pred)
accuracy
# Out:
# 0.9666666666666667

# %%
###MLFLOW tracking 
mlflow.set_tracking_uri(uri="http://127.0.0.1:5000")

###create a new MLFLOW experiment
 
mlflow.set_experiment("MLFLOW Quickstart")

with mlflow.start_run():
    ##log the hyperparameters
    mlflow.log_params(params)

    ##log the accuracy metrics
    mlflow.log_metric("accuracy",accuracy)

    #set a tag that we can use to remind ourselves what this run was for
    mlflow.set_tag("Training Info","Basic LR model for iris data ")

    ## Infer the model signature
    signature = infer_signature(X_train,lr.predict(X_train))

    ##log the model
    model_info = mlflow.sklearn.log_model(
        sk_model=lr,
        artifact_path ="iris_model",
        signature=signature,
        input_example=X_train,
        registered_model_name ="tracking-quickstart",


    )
# Out:
# 2024/12/13 09:53:20 INFO mlflow.tracking.fluent: Experiment with name 'MLFLOW Quickstart' does not exist. Creating a new experiment.
# Downloading artifacts: 100%|██████████| 7/7 [00:00<00:00, 426.89it/s]
# Successfully registered model 'tracking-quickstart'.
# 2024/12/13 09:53:23 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: tracking-quickstart, version 1
# 🏃 View run useful-boar-745 at: http://127.0.0.1:5000/#/experiments/218144751472446134/runs/c0b0778c693f45a187f58b0ddde763d1
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/218144751472446134
# Created version '1' of model 'tracking-quickstart'.

# %%
#define the hyper model parameters

params = {"solver":"newton-cg","max_iter":1000,"multi_class":"auto","random_state":1000}

##train the model
lr=LogisticRegression(**params)
lr.fit(X_train,y_train)
# Out:
# c:\Users\SESPL\Desktop\Mlops\mlflow\venv\lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# LogisticRegression(max_iter=1000, multi_class='auto', random_state=1000,
#                    solver='newton-cg')

# %%
## prediction on the test set
y_pred = lr.predict(X_test)
y_pred
# Out:
# array([1, 1, 0, 1, 2, 1, 1, 2, 1, 2, 1, 1, 2, 0, 0, 1, 2, 2, 2, 0, 0, 2,
#        2, 1, 2, 1, 1, 2, 2, 0])

# %%
accuracy=accuracy_score(y_test,y_pred)
accuracy
# Out:
# 0.9666666666666667

# %%
with mlflow.start_run():
    ##log the hyperparameters
    mlflow.log_params(params)

    ##log the accuracy metrics
    mlflow.log_metric("accuracy",accuracy)

    #set a tag that we can use to remind ourselves what this run was for
    mlflow.set_tag("Training Info","Basic LR model for iris data ")

    ## Infer the model signature
    signature = infer_signature(X_train,lr.predict(X_train))

    ##log the model
    model_info = mlflow.sklearn.log_model(
        sk_model=lr,
        artifact_path ="iris_model",
        signature=signature,
        input_example=X_train,
        registered_model_name ="tracking-quickstart",

    )
# Out:
# Downloading artifacts: 100%|██████████| 7/7 [00:00<?, ?it/s]
# Registered model 'tracking-quickstart' already exists. Creating a new version of this model...
# 2024/12/13 09:53:41 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: tracking-quickstart, version 2
# 🏃 View run defiant-sow-618 at: http://127.0.0.1:5000/#/experiments/218144751472446134/runs/4cf2170b1eb44b4b8ee4910265210217
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/218144751472446134
# Created version '2' of model 'tracking-quickstart'.

# %% [markdown]
# ###Inferencing and validating model

# %%
from mlflow.models import validate_serving_input

model_uri = 'runs:/229c8ce5d2934e03b47ee91acedafb87/iris_model'

# The model is logged with an input example. MLflow converts
# it into the serving payload format for the deployed model endpoint,
# and saves it to 'serving_input_payload.json'
serving_payload = """{
  "inputs": [
    [
      6.3,
      3.4,
    ],
    [
      4.9,
      3.1,
      1.5,
      0.2
    ],
    [
      4.8,
      3.4,
      1.6,
      0.2
    ],
    [
      5.7,
      2.9,
      4.2,
      1.3
    ],
    [
      6.9,
      3.1,
      4.9,
      1.5
    ],
    [
      7.1,
      3.0,
      5.9,
      2.1
    ],
    [
      5.5,
      2.6,
      4.4,
      1.2
    ],
    [
      6.5,
      3.0,
      5.2,
      2.0
    ],
    [
      5.0,
      3.0,
      1.6,
      0.2
    ],
    [
      4.4,
      3.2,
      1.3,A
      0.2
    ]
  ]
}"""

# Validate the serving payload works on the model
validate_serving_input(model_uri, serving_payload)
# Out:
# ---------------------------------------------------------------------------
# RestException                             Traceback (most recent call last)
# Cell In[17], line 734
#       8 serving_payload = """{
#       9   "inputs": [
#      10     [
#    (...)
#     730   ]
#     731 }"""
#     733 # Validate the serving payload works on the model
# --> 734 validate_serving_input(model_uri, serving_payload)
#
# File c:\Users\SESPL\Desktop\Mlops\mlflow\venv\lib\site-packages\mlflow\models\utils.py:1860, in validate_serving_input(model_uri, serving_input)
#    1857 output_dir = None if get_local_path_or_none(model_uri) else create_tmp_dir()
#    1859 try:
# -> 1860     pyfunc_model = mlflow.pyfunc.load_model(model_uri, dst_path=output_dir)
#    1861     parsed_input = _parse_json_data(
#    1862         serving_input,
#    1863         pyfunc_model.metadata,
#    1864         pyfunc_model.metadata.get_input_schema(),
#    1865     )
#    1866     return pyfunc_model.predict(parsed_input.data, params=parsed_input.params)
#
# File c:\Users\SESPL\Desktop\Mlops\mlflow\venv\lib\site-packages\mlflow\tracing\provider.py:268, in trace_disabled.<locals>.wrapper(*args, **kwargs)
#     266 disable()
#     267 try:
# --> 268     is_func_called, result = True, f(*args, **kwargs)
#     269 finally:
#     270     enable()
#
# File c:\Users\SESPL\Desktop\Mlops\mlflow\venv\lib\site-packages\mlflow\pyfunc\__init__.py:1029, in load_model(model_uri, suppress_warnings, dst_path, model_config)
#    1025         entity_list.append(Entity(job=job_entity))
#    1027     lineage_header_info = LineageHeaderInfo(entities=entity_list) if entity_list else None
# -> 1029 local_path = _download_artifact_from_uri(
#    1030     artifact_uri=model_uri, output_path=dst_path, lineage_header_info=lineage_header_info
#    1031 )
#    1033 if not suppress_warnings:
#    1034     model_requirements = _get_pip_requirements_from_model_path(local_path)
#
# File c:\Users\SESPL\Desktop\Mlops\mlflow\venv\lib\site-packages\mlflow\tracking\artifact_utils.py:108, in _download_artifact_from_uri(artifact_uri, output_path, lineage_header_info)
#     100 """
#     101 Args:
#     102     artifact_uri: The *absolute* URI of the artifact to download.
#    (...)
#     105     lineage_header_info: The model lineage header info to be consumed by lineage services.
#     106 """
#     107 root_uri, artifact_path = _get_root_uri_and_artifact_path(artifact_uri)
# --> 108 repo = get_artifact_repository(artifact_uri=root_uri)
#     110 if isinstance(repo, ModelsArtifactRepository):
#     111     return repo.download_artifacts(
#     112         artifact_path=artifact_path,
#     113         dst_path=output_path,
#     114         lineage_header_info=lineage_header_info,
#     115     )
#
# File c:\Users\SESPL\Desktop\Mlops\mlflow\venv\lib\site-packages\mlflow\store\artifact\artifact_repository_registry.py:131, in get_artifact_repository(artifact_uri)
#     118 def get_artifact_repository(artifact_uri: str) -> ArtifactRepository:
#     119     """
#     120     Get an artifact repository from the registry based on the scheme of artifact_uri
#     121
#    (...)
#     129         requirements.
#     130     """
# --> 131     return _artifact_repository_registry.get_artifact_repository(artifact_uri)
#
# File c:\Users\SESPL\Desktop\Mlops\mlflow\venv\lib\site-packages\mlflow\store\artifact\artifact_repository_registry.py:76, in ArtifactRepositoryRegistry.get_artifact_repository(self, artifact_uri)
#      71 if repository is None:
#      72     raise MlflowException(
#      73         f"Could not find a registered artifact repository for: {artifact_uri}. "
#      74         f"Currently registered schemes are: {list(self._registry.keys())}"
#      75     )
# ---> 76 return repository(artifact_uri)
#
# File c:\Users\SESPL\Desktop\Mlops\mlflow\venv\lib\site-packages\mlflow\store\artifact\runs_artifact_repo.py:26, in RunsArtifactRepository.__init__(self, artifact_uri)
#      23 from mlflow.store.artifact.artifact_repository_registry import get_artifact_repository
#      25 super().__init__(artifact_uri)
# ---> 26 uri = RunsArtifactRepository.get_underlying_uri(artifact_uri)
#      27 self.repo = get_artifact_repository(uri)
#
# File c:\Users\SESPL\Desktop\Mlops\mlflow\venv\lib\site-packages\mlflow\store\artifact\runs_artifact_repo.py:39, in RunsArtifactRepository.get_underlying_uri(runs_uri)
#      37 (run_id, artifact_path) = RunsArtifactRepository.parse_runs_uri(runs_uri)
#      38 tracking_uri = get_databricks_profile_uri_from_artifact_uri(runs_uri)
# ---> 39 uri = get_artifact_uri(run_id, artifact_path, tracking_uri)
#      40 assert not RunsArtifactRepository.is_runs_uri(uri)  # avoid an infinite loop
#      41 return add_databricks_profile_info_to_artifact_uri(uri, tracking_uri)
#
# File c:\Users\SESPL\Desktop\Mlops\mlflow\venv\lib\site-packages\mlflow\tracking\artifact_utils.py:52, in get_artifact_uri(run_id, artifact_path, tracking_uri)
#      46     raise MlflowException(
#      47         message="A run_id must be specified in order to obtain an artifact uri!",
#      48         error_code=INVALID_PARAMETER_VALUE,
#      49     )
#      51 store = _get_store(tracking_uri)
# ---> 52 run = store.get_run(run_id)
#      53 # Maybe move this method to RunsArtifactRepository so the circular dependency is clearer.
#      54 assert urllib.parse.urlparse(run.info.artifact_uri).scheme != "runs"  # avoid an infinite loop
#
# File c:\Users\SESPL\Desktop\Mlops\mlflow\venv\lib\site-packages\mlflow\store\tracking\rest_store.py:169, in RestStore.get_run(self, run_id)
#     159 """
#     160 Fetch the run from backend store
#     161
#    (...)
#     166     A single Run object if it exists, otherwise raises an Exception
#     167 """
#     168 req_body = message_to_json(GetRun(run_uuid=run_id, run_id=run_id))
# --> 169 response_proto = self._call_endpoint(GetRun, req_body)
#     170 return Run.from_proto(response_proto.run)
#
# File c:\Users\SESPL\Desktop\Mlops\mlflow\venv\lib\site-packages\mlflow\store\tracking\rest_store.py:82, in RestStore._call_endpoint(self, api, json_body, endpoint)
#      80     endpoint, method = _METHOD_TO_INFO[api]
#      81 response_proto = api.Response()
# ---> 82 return call_endpoint(self.get_host_creds(), endpoint, method, json_body, response_proto)
#
# File c:\Users\SESPL\Desktop\Mlops\mlflow\venv\lib\site-packages\mlflow\utils\rest_utils.py:370, in call_endpoint(host_creds, endpoint, method, json_body, response_proto, extra_headers)
#     367     call_kwargs["json"] = json_body
#     368     response = http_request(**call_kwargs)
# --> 370 response = verify_rest_response(response, endpoint)
#     371 response_to_parse = response.text
#     372 js_dict = json.loads(response_to_parse)
#
# File c:\Users\SESPL\Desktop\Mlops\mlflow\venv\lib\site-packages\mlflow\utils\rest_utils.py:240, in verify_rest_response(response, endpoint)
#     238 if response.status_code != 200:
#     239     if _can_parse_as_json_object(response.text):
# --> 240         raise RestException(json.loads(response.text))
#     241     else:
#     242         base_msg = (
#     243             f"API request to endpoint {endpoint} "
#     244             f"failed with error code {response.status_code} != 200"
#     245         )
#
# RestException: RESOURCE_DOES_NOT_EXIST: Run '229c8ce5d2934e03b47ee91acedafb87' not found

# %% [markdown]
# ## Load the model back for prediction as generic python function model

# %%
loaded_model=mlflow.pyfunc.load_model(model_info.model_uri)
predictions = loaded_model.predict(X_test)

iris_features_name = datasets.load_iris().feature_names

result =pd.DataFrame(X_test,columns=iris_features_name)
result["actual_class"] = y_test
result["predicted_class"]=predictions

# %%
result
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                 6.7               3.1                5.6               2.4
# 1                 5.6               2.5                3.9               1.1
# 2                 4.4               3.0                1.3               0.2
# 3                 5.5               3.5                1.3               0.2
# 4                 6.1               2.8                4.0               1.3
# 5                 6.7               2.5                5.8               1.8
# 6                 6.0               2.9                4.5               1.5
# 7                 4.5               2.3                1.3               0.3
# 8                 5.8               2.7                3.9               1.2
# 9                 6.2               2.2                4.5               1.5
# 10                6.0               2.2                5.0               1.5
# 11                5.6               2.9                3.6               1.3
# 12                4.9               3.1                1.5               0.1
# 13                5.4               3.4                1.7               0.2
# 14                6.7               3.0                5.0               1.7
# 15                5.1               2.5                3.0               1.1
# 16                4.9               3.6                1.4               0.1
# 17                5.8               2.7                5.1               1.9
# 18                4.4               2.9                1.4               0.2
# 19                6.0               2.7                5.1               1.6
# 20                5.8               2.7                4.1               1.0
# 21                5.7               2.5                5.0               2.0
# 22                6.6               2.9                4.6               1.3
# 23                5.4               3.7                1.5               0.2
# 24                6.7               3.3                5.7               2.1
# 25                6.0               3.4                4.5               1.6
# 26                4.3               3.0                1.1               0.1
# 27                4.7               3.2                1.6               0.2
# 28                4.8               3.0                1.4               0.1
# 29                7.7               3.0                6.1               2.3
#
#     actual_class  predicted_class
# 0              2                2
# 1              1                1
# 2              0                0
# 3              0                0
# 4              1                1
# 5              2                2
# 6              1                1
# 7              0                0
# 8              1                1
# 9              1                1
# 10             2                2
# 11             1                1
# 12             0                0
# 13             0                0
# 14             1                2
# 15             1                1
# 16             0                0
# 17             2                2
# 18             0                0
# 19             1                2
# 20             1                1
# 21             2                2
# 22             1                1
# 23             0                0
# 24             2                2
# 25             1                1
# 26             0                0
# 27             0                0
# 28             0                0
# 29             2                2

# %%
with mlflow.start_run():
    ##log the hyperparameters
    mlflow.log_params(params)

    ##log the accuracy metrics
    mlflow.log_metric("accuracy",1.0)

    #set a tag that we can use to remind ourselves what this run was for
    mlflow.set_tag("Training Info","Basic LR model for iris data ")

    ## Infer the model signature
    signature = infer_signature(X_train,lr.predict(X_train))

    ##log the model
    model_info = mlflow.sklearn.log_model(
        sk_model=lr,
        artifact_path ="iris_model",
        signature=signature,
        input_example=X_train


    )
# Out:
# 2024/12/13 09:56:29 WARNING mlflow.utils.environment: Encountered an unexpected error while inferring pip requirements (model URI: C:\Users\SESPL\AppData\Local\Temp\tmpfq9l9hgu\model\model.pkl, flavor: sklearn). Fall back to return ['scikit-learn==1.6.0', 'cloudpickle==3.1.0']. Set logging level to DEBUG to see the full traceback.
# Downloading artifacts: 100%|██████████| 7/7 [00:00<00:00, 877.68it/s]
# 🏃 View run welcoming-smelt-143 at: http://127.0.0.1:5000/#/experiments/218144751472446134/runs/637e447f68ff482db0258e8498f223d4
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/218144751472446134

# %%
##Inferencing from model from model registry

import mlflow.sklearn
model_name = "tracking-quickstart"
model_version ="latest"

model_uri=f"models:/{model_name}/{model_version}"

model = mlflow.sklearn.load_model(model_uri)
model
# Out:
# c:\Users\SESPL\Desktop\Mlops\mlflow\venv\lib\site-packages\mlflow\store\artifact\utils\models.py:31: FutureWarning: ``mlflow.tracking.client.MlflowClient.get_latest_versions`` is deprecated since 2.9.0. Model registry stages will be removed in a future major release. To learn more about the deprecation of model registry stages, see our migration guide here: https://mlflow.org/docs/latest/model-registry.html#migrating-from-stages
#   latest = client.get_latest_versions(name, None if stage is None else [stage])
# LogisticRegression(max_iter=1000, multi_class='auto', random_state=1000,
#                    solver='newton-cg')

# %%
y_pred_new = model.predict(X_test)
y_pred_new
# Out:
# array([2, 1, 0, 0, 1, 2, 1, 0, 1, 1, 2, 1, 0, 0, 2, 1, 0, 2, 0, 2, 1, 2,
#        1, 0, 2, 1, 0, 0, 0, 2])
